# %% [markdown]
# Create a flask-based web database for BibTex data. Should support inputting .bib files as a "collection" with a user-defined name. Database should pass user-entered SQLite statements through to database, and show columns for author list, journal, volume, etc. Turn this into a public GitHub repo

# %%
# testing pybtex parsing

from pybtex import database
import pybtex
bib_data = database.parse_file('hw_7_data/homework_7_refs.bib')
print(bib_data)
# Out:
# 0.24.0
# BibliographyData(
#   entries=OrderedCaseInsensitiveDict([
#     ('1998A&A...330..515F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1998A%26A...330..515F'),
#         ('Date-Added', '2010-03-30 13:55:36 -0700'),
#         ('Date-Modified', '2010-03-30 13:55:36 -0700'),
#         ('Journal', '\\aap'),
#         ('Keywords', 'STARS: VARIABLES: RR LYRAES, GALAXY: GLOBULAR CLUSTERS, GALAXIES: MAGELLANIC CLOUDS'),
#         ('Month', 'February'),
#         ('Pages', '515-520'),
#         ('Title', '{The absolute magnitudes of RR Lyraes from HIPPARCOS parallaxes and proper motions}'),
#         ('Volume', '330'),
#         ('Year', '1998'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Fernley}, J.'), Person('{Barnes}, T. G.'), Person('{Skillen}, I.'), Person('{Hawley}, S. L.'), Person('{Hanley}, C. J.'), Person('{Evans}, D. W.'), Person('{Solano}, E.'), Person('{Garrido}, R.')])]))),
#     ('2001AJ....122.2587C', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2001AJ....122.2587C'),
#         ('Date-Added', '2010-03-28 20:49:58 -0700'),
#         ('Date-Modified', '2010-03-28 20:49:58 -0700'),
#         ('Doi', '10.1086/323719'),
#         ('Eprint', 'arXiv:astro-ph/0108024'),
#         ('Journal', '\\aj'),
#         ('Keywords', 'Stars: Binaries: Eclipsing, Stars: Variables: Cepheids, Galaxy: Globular Clusters: General, Stars: Variables: RR Lyrae Variable, Stars: Horizontal-Branch, Stars: Oscillations'),
#         ('Month', 'November'),
#         ('Pages', '2587-2599'),
#         ('Title', '{Variable Stars in Galactic Globular Clusters}'),
#         ('Volume', '122'),
#         ('Year', '2001'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Clement}, C. M.'), Person('{Muzzin}, A.'), Person('{Dufton}, Q.'), Person('{Ponnampalam}, T.'), Person('{Wang}, J.'), Person('{Burford}, J.'), Person('{Richardson}, A.'), Person('{Rosebery}, T.'), Person('{Rowe}, J.'), Person('{Hogg}, H. S.')])]))),
#     ('2007A&A...474..653V', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2007A%26A...474..653V'),
#         ('Archiveprefix', 'arXiv'),
#         ('Date-Added', '2009-11-30 11:40:22 -0800'),
#         ('Date-Modified', '2009-11-30 11:40:22 -0800'),
#         ('Doi', '10.1051/0004-6361:20078357'),
#         ('Eprint', '0708.1752'),
#         ('Journal', '\\aap'),
#         ('Keywords', 'space vehicles: instruments, methods: data analysis, catalogs, astrometry, instrumentation: miscellaneous'),
#         ('Month', 'November'),
#         ('Pages', '653-664'),
#         ('Title', '{Validation of the new Hipparcos reduction}'),
#         ('Volume', '474'),
#         ('Year', '2007'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{van Leeuwen}, F.')])]))),
#     ('1994ApJ...427..628F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1994ApJ...427..628F'),
#         ('Date-Added', '2009-11-12 12:45:24 -0800'),
#         ('Date-Modified', '2009-11-12 12:45:24 -0800'),
#         ('Doi', '10.1086/174172'),
#         ('Journal', '\\apj'),
#         ('Keywords', 'ASTROMETRY, ASTRONOMICAL PHOTOMETRY, CALIBRATING, CEPHEID VARIABLES, DISTANCE, SCALE (RATIO), SPIRAL GALAXIES, DATA REDUCTION, DATA SAMPLING, HUBBLE CONSTANT, HUBBLE SPACE TELESCOPE, INTERSTELLAR EXTINCTION, RED SHIFT, STELLAR LUMINOSITY, STELLAR MAGNITUDE'),
#         ('Month', 'June'),
#         ('Pages', '628-655'),
#         ('Title', '{The Hubble Space Telescope Extragalactic Distance Scale Key Project. 1: The discovery of Cepheids and a new distance to M81}'),
#         ('Volume', '427'),
#         ('Year', '1994'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Freedman}, W. L.'), Person('{Hughes}, S. M.'), Person('{Madore}, B. F.'), Person('{Mould}, J. R.'), Person('{Lee}, M. G.'), Person('{Stetson}, P.'), Person('{Kennicutt}, R. C.'), Person('{Turner}, A.'), Person('{Ferrarese}, L.'), Person('{Ford}, H.'), Person('{Graham}, J. A.'), Person('{Hill}, R.'), Person('{Hoessel}, J. G.'), Person('{Huchra}, J.'), Person('{Illingworth}, G. D.')])]))),
#     ('2006ASPC..351..751B', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2006ASPC..351..751B'),
#         ('Booktitle', 'Astronomical Data Analysis Software and Systems XV'),
#         ('Date-Added', '2009-11-12 09:23:44 -0800'),
#         ('Date-Modified', '2009-11-12 09:23:44 -0800'),
#         ('Month', 'July'),
#         ('Pages', '751-+'),
#         ('Series', 'Astronomical Society of the Pacific Conference Series'),
#         ('Title', '{Autonomous Observing and Control Systems for PAIRITEL, a 1.3m Infrared Imaging Telescope}'),
#         ('Volume', '351'),
#         ('Year', '2006'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Bloom}, J. S.'), Person('{Starr}, D. L.'), Person('{Blake}, C. H.'), Person('{Skrutskie}, M. F.'), Person('{Falco}, E. E.')]), ('Editor', [Person('{C.~Gabriel, C.~Arviset, D.~Ponz, \\& S.~Enrique}')])]))),
#     ('1996A&AS..117..393B', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1996A%26AS..117..393B'),
#         ('Date-Added', '2009-11-12 09:12:23 -0800'),
#         ('Date-Modified', '2009-11-12 09:12:23 -0800'),
#         ('Journal', '\\aaps'),
#         ('Keywords', 'METHODS: DATA ANALYSIS, TECHNIQUES: IMAGE PROCESSING, GALAXIES: PHOTOMETRY'),
#         ('Month', 'June'),
#         ('Pages', '393-404'),
#         ('Title', '{SExtractor: Software for source extraction.}'),
#         ('Volume', '117'),
#         ('Year', '1996'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Bertin}, E.'), Person('{Arnouts}, S.')])]))),
#     ('1997ApJ...486...60D', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1997ApJ...486...60D'),
#         ('Date-Added', '2009-11-11 13:29:54 -0800'),
#         ('Date-Modified', '2009-11-11 13:29:54 -0800'),
#         ('Doi', '10.1086/304496'),
#         ('Journal', '\\apj'),
#         ('Keywords', 'STARS: VARIABLES: CEPHEIDS, COSMOLOGY: DISTANCE SCALE, GALAXY: OPEN CLUSTERS AND ASSOCIATIONS: GENERAL, STARS: OSCILLATIONS'),
#         ('Month', 'September'),
#         ('Pages', '60-+'),
#         ('Title', '{Improved Calibration of Cosmic Distance Scale by Cepheid Pulsation Parallaxes}'),
#         ('Volume', '486'),
#         ('Year', '1997'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{di Benedetto}, G. P.')])]))),
#     ('1997ESASP.402..657S', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1997ESASP.402..657S'),
#         ('Booktitle', "Hipparcos - Venice '97"),
#         ('Date-Added', '2009-11-11 13:28:41 -0800'),
#         ('Date-Modified', '2009-11-11 13:28:41 -0800'),
#         ('Month', 'August'),
#         ('Pages', '657-660'),
#         ('Series', 'ESA Special Publication'),
#         ('Title', '{HIPPARCOS Parallaxes of the Nearest Cepheids -- Implicative of Binarity}'),
#         ('Volume', '402'),
#         ('Year', '1997'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Szabados}, L.')])]))),
#     ('2003LNP...635..281R', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..281R'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:22:09 -0800'),
#         ('Date-Modified', '2009-11-11 13:22:09 -0800'),
#         ('Pages', '281-305'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{The Globular Cluster Luminosity Function: New Progress in Understanding an Old Distance Indicator}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Richtler}, T.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..265W', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..265W'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:21:18 -0800'),
#         ('Date-Modified', '2009-11-11 13:21:18 -0800'),
#         ('Pages', '265-279'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Distances to Local Group Galaxies}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Walker}, A. R.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..243C', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..243C'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:20:01 -0800'),
#         ('Date-Modified', '2009-11-11 13:20:01 -0800'),
#         ('Pages', '243-263'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Extragalactic Distances from Planetary Nebulae}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Ciardullo}, R.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..229G', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..229G'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:19:25 -0800'),
#         ('Date-Modified', '2009-11-11 13:19:25 -0800'),
#         ('Pages', '229-241'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Novae as Distance Indicators}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Gilmozzi}, R.'), Person('{Della Valle}, M.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..203H', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..203H'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:18:19 -0800'),
#         ('Date-Modified', '2009-11-11 13:18:19 -0800'),
#         ('Pages', '203-227'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Models for Type Ia Supernovae and Cosmology}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{H{\\"o}flich}, P.'), Person('{Gerardy}, C.'), Person('{Linder}, E.'), Person('{et al.}')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..187S', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..187S'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:17:32 -0800'),
#         ('Date-Modified', '2009-11-11 13:17:32 -0800'),
#         ('Pages', '187-202'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Type Ia Supernovae and Cosmology}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Suntzeff}, N. B.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..175P', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..175P'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:16:39 -0800'),
#         ('Date-Modified', '2009-11-11 13:16:39 -0800'),
#         ('Pages', '175-185'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Supernovae as Cosmological Standard Candles}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Phillips}, M. M.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..123K', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..123K'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:15:22 -0800'),
#         ('Date-Modified', '2009-11-11 13:15:22 -0800'),
#         ('Pages', '123-148'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Blue Supergiants as a Tool for Extragalactic Distances Theoretical Concepts}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Kudritzki}, {R.-P.}'), Person('{Przybilla}, N.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635..105C', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635..105C'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:14:25 -0800'),
#         ('Date-Modified', '2009-11-11 13:14:25 -0800'),
#         ('Pages', '105-122'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Globular Cluster Distances from RR Lyrae Stars}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Cacciari}, C.'), Person('{Clementini}, G.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635...85B', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635...85B'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:12:56 -0800'),
#         ('Date-Modified', '2009-11-11 13:12:56 -0800'),
#         ('Pages', '85-104'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{RR Lyrae Distance Scale: Theory and Observations}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Bono}, G.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635...71S', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635...71S'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:11:43 -0800'),
#         ('Date-Modified', '2009-11-11 13:11:43 -0800'),
#         ('Pages', '71-83'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{The Cepheid Calibration of Type Ia Supernovae as Standard Candles}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Saha}, A.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635...45F', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635...45F'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:07:08 -0800'),
#         ('Date-Modified', '2009-11-11 13:07:08 -0800'),
#         ('Pages', '45-70'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Current Uncertainties in the Use of Cepheids as Distance Indicators}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Feast}, M.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635...21F', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635...21F'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:03:45 -0800'),
#         ('Date-Modified', '2009-11-11 13:03:45 -0800'),
#         ('Pages', '21-44'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{Calibration of the Distance Scale from Cepheids}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person("{Fouqu{\\'e}}, P."), Person('{Storm}, J.'), Person('{Gieren}, W.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2003LNP...635....1M', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2003LNP...635....1M'),
#         ('Booktitle', 'Stellar Candles for the Extragalactic Distance Scale'),
#         ('Date-Added', '2009-11-11 13:02:00 -0800'),
#         ('Date-Modified', '2009-11-11 13:02:00 -0800'),
#         ('Pages', '1-20'),
#         ('Series', 'Lecture Notes in Physics, Berlin Springer Verlag'),
#         ('Title', '{The HST Key Project on the Extragalactic Distance Scale: A Search for Three Numbers}'),
#         ('Volume', '635'),
#         ('Year', '2003'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Madore}, B. F.'), Person('{Freedman}, W. L.')]), ('Editor', [Person('{D.~Alloin \\& W.~Gieren}')])]))),
#     ('2008MNRAS.389.1336K', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2008MNRAS.389.1336K'),
#         ('Archiveprefix', 'arXiv'),
#         ('Date-Added', '2009-11-11 12:59:31 -0800'),
#         ('Date-Modified', '2009-11-11 12:59:31 -0800'),
#         ('Doi', '10.1111/j.1365-2966.2008.13644.x'),
#         ('Eprint', '0807.2057'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'stars: fundamental parameters , supergiants , Cepheids'),
#         ('Month', 'September'),
#         ('Pages', '1336-1344'),
#         ('Title', '{Reddenings of FGK supergiants and classical Cepheids from spectroscopic data}'),
#         ('Volume', '389'),
#         ('Year', '2008'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Kovtyukh}, V. V.'), Person('{Soubiran}, C.'), Person('{Luck}, R. E.'), Person('{Turner}, D. G.'), Person('{Belik}, S. I.'), Person('{Andrievsky}, S. M.'), Person('{Chekhonadskikh}, F. A.')])]))),
#     ('1987ARA&A..25..345F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1987ARA%26A..25..345F'),
#         ('Date-Added', '2009-11-11 12:57:54 -0800'),
#         ('Date-Modified', '2009-11-11 12:57:54 -0800'),
#         ('Doi', '10.1146/annurev.aa.25.090187.002021'),
#         ('Journal', '\\araa'),
#         ('Keywords', 'ASTROMETRY, ASTROPHYSICS, CEPHEID VARIABLES, ABUNDANCE, INFRARED SPECTRA, INTERSTELLAR EXTINCTION, MAGELLANIC CLOUDS, STELLAR PARALLAX, UBV SPECTRA'),
#         ('Pages', '345-375'),
#         ('Title', '{Cepheids as distance indicators}'),
#         ('Volume', '25'),
#         ('Year', '1987'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Feast}, M. W.'), Person('{Walker}, A. R.')])]))),
#     ('2006ARA&A..44...93S', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2006ARA%26A..44...93S'),
#         ('Date-Added', '2009-11-11 12:56:57 -0800'),
#         ('Date-Modified', '2009-11-11 12:56:57 -0800'),
#         ('Doi', '10.1146/annurev.astro.43.072103.150612'),
#         ('Journal', '\\araa'),
#         ('Month', 'September'),
#         ('Pages', '93-140'),
#         ('Title', '{Absolute Magnitude Calibrations of Population I and II Cepheids and Other Pulsating Variables in the Instability Strip of the Hertzsprung-Russell Diagram}'),
#         ('Volume', '44'),
#         ('Year', '2006'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Sandage}, A.'), Person('{Tammann}, G. A.')])]))),
#     ('2002AJ....124.1213D', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2002AJ....124.1213D'),
#         ('Date-Added', '2009-11-11 12:54:52 -0800'),
#         ('Date-Modified', '2009-11-11 12:54:52 -0800'),
#         ('Doi', '10.1086/341644'),
#         ('Journal', '\\aj'),
#         ('Keywords', 'Stars: Variables: Cepheids, Cosmology: Distance Scale'),
#         ('Month', 'August'),
#         ('Pages', '1213-1220'),
#         ('Title', '{On the Absolute Calibration of the Cepheid Distance Scale Using Hipparcos Parallaxes}'),
#         ('Volume', '124'),
#         ('Year', '2002'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Di Benedetto}, G. P.')])]))),
#     ('1978MNRAS.183..569D', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1978MNRAS.183..569D'),
#         ('Date-Added', '2009-11-11 12:52:28 -0800'),
#         ('Date-Modified', '2009-11-11 12:52:28 -0800'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'CEPHEID VARIABLES, STELLAR LUMINOSITY, STELLAR SPECTROPHOTOMETRY, INTERSTELLAR EXTINCTION, LIGHT CURVE, LINE SPECTRA, STAR CLUSTERS, STELLAR SPECTRA, UBV SPECTRA'),
#         ('Month', 'June'),
#         ('Pages', '569-583'),
#         ('Title', '{Reddenings of Cepheids using BVI photometry}'),
#         ('Volume', '183'),
#         ('Year', '1978'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Dean}, J. F.'), Person('{Warren}, P. R.'), Person('{Cousins}, A. W. J.')])]))),
#     ('2008JPhCS.118a2010E', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2008JPhCS.118a2010E'),
#         ('Archiveprefix', 'arXiv'),
#         ('Date-Added', '2009-11-10 18:18:21 -0800'),
#         ('Date-Modified', '2009-11-10 18:18:21 -0800'),
#         ('Doi', '10.1088/1742-6596/118/1/012010'),
#         ('Eprint', '0712.3797'),
#         ('Journal', 'Journal of Physics Conference Series'),
#         ('Month', 'October'),
#         ('Number', '1'),
#         ('Pages', '012010-+'),
#         ('Title', '{Variable stars across the observational HR diagram}'),
#         ('Volume', '118'),
#         ('Year', '2008'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Eyer}, L.'), Person('{Mowlavi}, N.')])]))),
#     ('1995AJ....110.1476K', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1995AJ....110.1476K'),
#         ('Doi', '10.1086/117621'),
#         ('Journal', '\\aj'),
#         ('Keywords', 'DISTANCE SCALE'),
#         ('Month', 'October'),
#         ('Pages', '1476-+'),
#         ('Title', '{Measuring the Hubble Constant with the Hubble Space Telescope}'),
#         ('Volume', '110'),
#         ('Year', '1995'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Kennicutt}, Jr., R. C.'), Person('{Freedman}, W. L.'), Person('{Mould}, J. R.')])]))),
#     ('1908AnHar..60...87L', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1908AnHar..60...87L'),
#         ('Journal', 'Annals of Harvard College Observatory'),
#         ('Pages', '87-108'),
#         ('Title', '{1777 variables in the Magellanic Clouds}'),
#         ('Volume', '60'),
#         ('Year', '1908'),
#         ('Bdsk-Url-1', 'http://adsabs.harvard.edu/abs/1908AnHar..60...87L')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Leavitt}, H. S.')])]))),
#     ('1912HarCi.173....1L', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1912HarCi.173....1L'),
#         ('Journal', 'Harvard College Observatory Circular'),
#         ('Month', 'March'),
#         ('Pages', '1-3'),
#         ('Title', '{Periods of 25 Variable Stars in the Small Magellanic Cloud.}'),
#         ('Volume', '173'),
#         ('Year', '1912'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Leavitt}, H. S.'), Person('{Pickering}, E. C.')])]))),
#     ('2001ApJ...553...47F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2001ApJ...553...47F'),
#         ('Doi', '10.1086/320638'),
#         ('Eprint', 'arXiv:astro-ph/0012376'),
#         ('Journal', '\\apj'),
#         ('Keywords', 'Stars: Variables: Cepheids, Cosmology: Observations, Cosmology: Distance Scale, Galaxies: Distances and Redshifts'),
#         ('Month', 'May'),
#         ('Pages', '47-72'),
#         ('Title', '{Final Results from the Hubble Space Telescope Key Project to Measure the Hubble Constant}'),
#         ('Volume', '553'),
#         ('Year', '2001'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Freedman}, W. L.'), Person('{Madore}, B. F.'), Person('{Gibson}, B. K.'), Person('{Ferrarese}, L.'), Person('{Kelson}, D. D.'), Person('{Sakai}, S.'), Person('{Mould}, J. R.'), Person('{Kennicutt}, Jr., R. C.'), Person('{Ford}, H. C.'), Person('{Graham}, J. A.'), Person('{Huchra}, J. P.'), Person('{Hughes}, S. M. G.'), Person('{Illingworth}, G. D.'), Person('{Macri}, L. M.'), Person('{Stetson}, P. B.')])]))),
#     ('1997ESASP1200.....P', Entry('proceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1997ESASP1200.....P'),
#         ('Booktitle', 'ESA Special Publication'),
#         ('Keywords', 'SPACE ASTROMETRY, STAR CATALOGS, POSITIONS, ARTIFICIAL SATELLITES'),
#         ('Series', 'ESA Special Publication'),
#         ('Title', '{The HIPPARCOS and TYCHO catalogues. Astrometric and photometric star catalogues derived from the ESA HIPPARCOS Space Astrometry Mission}'),
#         ('Volume', '1200'),
#         ('Year', '1997'),
#         ('Bdsk-Url-1', 'http://adsabs.harvard.edu/abs/1997ESASP1200.....P')],
#       persons=OrderedCaseInsensitiveDict([('Editor', [Person('{M.~A.~C.~Perryman \\& ESA}')])]))),
#     ('1997MNRAS.286L...1F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1997MNRAS.286L...1F'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'CEPHEIDS, DISTANCE SCALE'),
#         ('Month', 'March'),
#         ('Pages', 'L1-L5'),
#         ('Title', '{The Cepheid period-luminosity zero-point from HIPPARCOS trigonometrical parallaxes}'),
#         ('Volume', '286'),
#         ('Year', '1997'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Feast}, M. W.'), Person('{Catchpole}, R. M.')])]))),
#     ('1998A&A...335L..81L', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1998A%26A...335L..81L'),
#         ('Eprint', 'arXiv:astro-ph/9805215'),
#         ('Journal', '\\aap'),
#         ('Keywords', 'LMC, LUMINOSITY CALIBRATION, RR LYRAE, CEPHEIDS'),
#         ('Month', 'July'),
#         ('Pages', 'L81-L84'),
#         ('Title', '{The LMC distance modulus from HIPPARCOS RR Lyrae and classical Cepheid data}'),
#         ('Volume', '335'),
#         ('Year', '1998'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Luri}, X.'), Person('{Gomez}, A. E.'), Person('{Torra}, J.'), Person('{Figueras}, F.'), Person('{Mennessier}, M. O.')])]))),
#     ('1997MNRAS.287..955V', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1997MNRAS.287..955V'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'ASTROMETRY, STARS: DISTANCES, STARS: FUNDAMENTAL PARAMETERS, STARS: VARIABLES: OTHER, MAGELLANIC CLOUDS, DISTANCE SCALE'),
#         ('Month', 'June'),
#         ('Pages', '955-960'),
#         ('Title', '{First results from HIPPARCOS trigonometrical parallaxes of Mira-type variables}'),
#         ('Volume', '287'),
#         ('Year', '1997'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{van Leeuwen}, F.'), Person('{Feast}, M. W.'), Person('{Whitelock}, P. A.'), Person('{Yudin}, B.')])]))),
#     ('2006MNRAS.372.1675S', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2006MNRAS.372.1675S'),
#         ('Doi', '10.1111/j.1365-2966.2006.10962.x'),
#         ('Eprint', 'arXiv:astro-ph/0608397'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'methods: observational, techniques: photometric, stars: distances, stars: variables: other, infrared: stars'),
#         ('Month', 'November'),
#         ('Pages', '1675-1680'),
#         ('Title', '{The RR Lyrae period-K-luminosity relation for globular clusters: an observational approach}'),
#         ('Volume', '372'),
#         ('Year', '2006'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Sollima}, A.'), Person('{Cacciari}, C.'), Person('{Valenti}, E.')])]))),
#     ('2008arXiv0806.3019F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2008arXiv0806.3019F'),
#         ('Archiveprefix', 'arXiv'),
#         ('Eprint', '0806.3019'),
#         ('Journal', 'ArXiv e-prints'),
#         ('Keywords', 'Astrophysics'),
#         ('Month', 'June'),
#         ('Title', '{Galactic and Extragalactic Distance Scales: The Variable Star Project}'),
#         ('Year', '2008'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Feast}, M. W.')])]))),
#     ('2008ApJ...679...71F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2008ApJ...679...71F'),
#         ('Archiveprefix', 'arXiv'),
#         ('Doi', '10.1086/586701'),
#         ('Eprint', '0801.2275'),
#         ('Journal', '\\apj'),
#         ('Keywords', 'Stars: Variables: Cepheids, Cosmology: Distance Scale, Infrared: Stars, Galaxies: Magellanic Clouds'),
#         ('Month', 'May'),
#         ('Pages', '71-75'),
#         ('Title', '{The Cepheid Period-Luminosity Relation at Mid-Infrared Wavelengths. I. First-Epoch LMC Data}'),
#         ('Volume', '679'),
#         ('Year', '2008'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Freedman}, W. L.'), Person('{Madore}, B. F.'), Person('{Rigby}, J.'), Person('{Persson}, S. E.'), Person('{Sturch}, L.')])]))),
#     ('2008MNRAS.386.2115F', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2008MNRAS.386.2115F'),
#         ('Archiveprefix', 'arXiv'),
#         ('Doi', '10.1111/j.1365-2966.2008.13181.x'),
#         ('Eprint', '0803.0466'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'stars: distances , Cepheids , Magellanic Clouds , distance scale'),
#         ('Month', 'June'),
#         ('Pages', '2115-2134'),
#         ('Title', '{The luminosities and distance scales of type II Cepheid and RR Lyrae variables}'),
#         ('Volume', '386'),
#         ('Year', '2008'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Feast}, M. W.'), Person('{Laney}, C. D.'), Person('{Kinman}, T. D.'), Person('{van Leeuwen}, F.'), Person('{Whitelock}, P. A.')])]))),
#     ('1998salg.conf..263M', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/1998salg.conf..263M'),
#         ('Booktitle', 'Stellar astrophysics for the local group: VIII Canary Islands Winter School of Astrophysics'),
#         ('Pages', '263-+'),
#         ('Title', '{Calibration of the Extragalactic Distance Scale}'),
#         ('Year', '1998'),
#         ('Bdsk-Url-1', 'http://nedwww.ipac.caltech.edu/level5/Cepheids/frames.html')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Madore}, B. F.'), Person('{Freedman}, W. L.')]), ('Editor', [Person("{A.~Aparicio, A.~Herrero, \\& F.~S{\\'a}nchez}")])]))),
#     ('2006MNRAS.370.1979M', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2006MNRAS.370.1979M'),
#         ('Doi', '10.1111/j.1365-2966.2006.10620.x'),
#         ('Eprint', 'arXiv:astro-ph/0606609'),
#         ('Journal', '\\mnras'),
#         ('Keywords', 'stars: Population II: stars: variables: other: globular clusters: general: infrared: stars, stars: Population II, stars: variables: other, globular clusters: general, infrared: stars'),
#         ('Month', 'August'),
#         ('Pages', '1979-1990'),
#         ('Title', '{The period-luminosity relation for type II Cepheids in globular clusters}'),
#         ('Volume', '370'),
#         ('Year', '2006'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Matsunaga}, N.'), Person('{Fukushi}, H.'), Person('{Nakada}, Y.'), Person("{Tanab{\\'e}}, T."), Person('{Feast}, M. W.'), Person('{Menzies}, J. W.'), Person('{Ita}, Y.'), Person('{Nishiyama}, S.'), Person('{Baba}, D.'), Person('{Naoi}, T.'), Person('{Nakaya}, H.'), Person('{Kawadu}, T.'), Person('{Ishihara}, A.'), Person('{Kato}, D.')])]))),
#     ('2009ASPC..411..493S', Entry('inproceedings',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2009ASPC..411..493S'),
#         ('Booktitle', 'Astronomical Society of the Pacific Conferenc
#         e Series'),
#         ('Month', 'September'),
#         ('Pages', '493-+'), ('Series', 'Astronomical Society of the Pacific Conference Series'),
#         ('Title', '{The Berkeley Transient Classification Pipeline: Deriving Real-time Knowledge from Time-domain Surveys}'),
#         ('Volume', '411'),
#         ('Year', '2009'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Starr}, D. L.'), Person('{Bloom}, J. S.'), Person('{Brewer}, J. M.'), Person('{Butler}, N. R.'), Person('{Poznanski}, D.'), Person('{Rischard}, M.'), Person('{Klein}, C.')]), ('Editor', [Person('{D.~A.~Bohlender, D.~Durand, \\& P.~Dowler}')])]))),
#     ('2006AJ....132.1014C', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2006AJ....132.1014C'),
#         ('Doi', '10.1086/505745'),
#         ('Eprint', 'arXiv:astro-ph/0605569'),
#         ('Journal', '\\aj'),
#         ('Keywords', 'globular clusters: individual (NGC 6441), globular clusters: individual (NGC 6388), Stars: Evolution, Stars: Variables: Other'),
#         ('Month', 'September'),
#         ('Pages', '1014-1022'),
#         ('Title', '{Image-Subtraction Photometry of Variable Stars in the Globular Clusters NGC 6388 and NGC 6441}'),
#         ('Volume', '132'),
#         ('Year', '2006'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Corwin}, T. M.'), Person('{Sumerel}, A. N.'), Person('{Pritzl}, B. J.'), Person('{Smith}, H. A.'), Person('{Catelan}, M.'), Person('{Sweigart}, A. V.'), Person('{Stetson}, P. B.')])]))),
#     ('2009MmSAI..80...97C', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2009MmSAI..80...97C'),
#         ('Journal', 'Memorie della Societa Astronomica Italiana'),
#         ('Keywords', 'Space vehicles: instruments, Stars: fundamental parameters, Galaxy: fundamental parameters, Galaxies: stellar content, Cosmology: observations'),
#         ('Pages', '97-+'),
#         ('Title', '{GAIA: the mission and (some of) its scientific applications .}'),
#         ('Volume', '80'),
#         ('Year', '2009'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Cacciari}, C.')])]))),
#     ('2006AJ....131.1163S', Entry('article',
#       fields=[
#         ('Adsnote', 'Provided by the SAO/NASA Astrophysics Data System'),
#         ('Adsurl', 'http://adsabs.harvard.edu/abs/2006AJ....131.1163S'),
#         ('Doi', '10.1086/498708'),
#         ('Journal', '\\aj'),
#         ('Keywords', 'Catalogs, Infrared: General, Surveys'),
#         ('Month', 'February'),
#         ('Pages', '1163-1183'),
#         ('Title', '{The Two Micron All Sky Survey (2MASS)}'),
#         ('Volume', '131'),
#         ('Year', '2006'),
#         ('Bdsk-File-1', '...')],
#       persons=OrderedCaseInsensitiveDict([('Author', [Person('{Skrutskie}, M. F.'), Person('{Cutri}, R. M.'), Person('{Stiening}, R.'), Person('{Weinberg}, M. D.'), Person('{Schneider}, S.'), Person('{Carpenter}, J. M.'), Person('{Beichman}, C.'), Person('{Capps}, R.'), Person('{Chester}, T.'), Person('{Elias}, J.'), Person('{Huchra}, J.'), Person('{Liebert}, J.'), Person('{Lonsdale}, C.'), Person('{Monet}, D. G.'), Person('{Price}, S.'), Person('{Seitzer}, P.'), Person('{Jarrett}, T.'), Person('{Kirkpatrick}, J. D.'), Person('{Gizis}, J. E.'), Person('{Howard}, E.'), Person('{Evans}, T.'), Person('{Fowler}, J.'), Person('{Fullmer}, L.'), Person('{Hurt}, R.'), Person('{Light}, R.'), Person('{Kopan}, E. L.'), Person('{Marsh}, K. A.'), Person('{McCallon}, H. L.'), Person('{Tam}, R.'), Person('{Van Dyk}, S.'), Person('{Wheelock}, S.')])])))]),
#
#   preamble=[])

# %%
# Web server
# %%writefile bibtex_server.py
import flask
import flask_sqlalchemy
import flask_restless
import pybtex

app = flask.Flask(__name__)
app.config["DEBUG"] = True
app.config["SQLALCHEMY_DATABASE_URI"] = "sqlite:////tmp/test_new.db"
app.config["SQLALCHEMY_TRACK_MODIFICATIONS"] = False

db = flask_sqlalchemy.SQLAlchemy(app)

class Member(db.Model):
        # __tablename __ = "newsletter_members"
        id = db.Column(db.Integer,primary_key=True)
        last_name = db.Column(db.String(50))
        first_name = db.Column(db.String(120))
        email = db.Column(db.String(120),unique=True)

db.create_all()

manager = flask_restless.APIManager(app,flask_sqlalchemy_db=db)

manager.create_api(Member,methods=["GET","POST"])



if __name__ == "__main__":
    app.run(port=5021)
